# %% [markdown]
# ### Import the necessary packages for Link between PostgreSQL to PyBook

# %%
import pandas as pd
import psycopg2 as db
from elasticsearch import Elasticsearch

# %% [markdown]
# ### Link the Elasticsearch with PostgreSQL

# %%
# Link between Postgre and Psycopg
connString = "dbname='P2M3_Daffa_Darwin' host='localhost' user='postgres' password='Kotobuk!27'"
conn = db.connect(connString)

# %%
# Define the variable of the table from PostgreSQL
df = pd.read_sql("select * from table_m3", conn)

# Call the set variable
df
# Out:
# C:\Users\Daffa\AppData\Local\Temp\ipykernel_4040\1577770616.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from table_m3", conn)
#       invoice_id branch       city customer_type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# ...

# %%
# Save the generated data from PostgreSQL to csv
df.to_csv('supermarketsales_clean.csv')
print("the data has been saved")
# Out:
# the data has been saved

# %%
es = Elasticsearch() 
df=pd.read_csv('supermarketsales_clean.csv')
for i,r in df.iterrows():
    doc=r.to_json()
    res=es.index(index="frompostgresql", doc_type="doc", body=doc)
    print(res)
# Out:
# d:\Miniconda\envs\BSD-005\lib\site-packages\elasticsearch\connection\base.py:208: ElasticsearchWarning: [types removal] Specifying types in document index requests is deprecated, use the typeless endpoints instead (/{index}/_doc/{id}, /{index}/_doc, or /{index}/_create/{id}).
#   warnings.warn(message, category=ElasticsearchWarning)
# {'_index': 'frompostgresql', '_type': 'doc', '_id': 'NwMItY8BIt1451U2OHAU', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'frompostgresql', '_type': 'doc', '_id': 'OAMItY8BIt1451U2OHBv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'frompostgresql', '_type': 'doc', '_id': 'OQMItY8BIt1451U2OHCy', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# ...
