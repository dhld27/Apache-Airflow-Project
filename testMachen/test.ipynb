# %%
# Import Library of Pandas
import pandas as pd

# %%
# Set variable for dataset
df = pd.read_csv('P2M3_Daffa_Darwin_data_raw.csv')

# %%
# call the variable of dataset
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
print(df["Total"].min())
print(df["Total"].max())
# Out:
# 10.6785
# 1042.65

# %%
df["City"].mode()
# Out:
# 0    Yangon
# Name: City, dtype: object

# %%
# check the dataset's types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# switch the type format
df["Date"] = pd.to_datetime(df["Date"])

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_id               1000 non-null   object
#  1   branch                   1000 non-null   object
#  2   city                     1000 non-null   object
#  3   customer_type            1000 non-null   object
#  4   gender                   1000 non-null   object
#  5   product_line             1000 non-null   object
#  6   unit_price               1000 non-null   float64
#  7   quantity                 1000 non-null   int64
#  8   tax_5%                   1000 non-null   float64
#  9   total                    1000 non-null   float64
#  10  date                     1000 non-null   datetime64[ns]
#  11  time                     1000 non-null   object
#  12  payment                  1000 non-null   object
# ...

# %%
df["time"] = df["time"].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_id               1000 non-null   object
#  1   branch                   1000 non-null   object
#  2   city                     1000 non-null   object
#  3   customer_type            1000 non-null   object
#  4   gender                   1000 non-null   object
#  5   product_line             1000 non-null   object
#  6   unit_price               1000 non-null   float64
#  7   quantity                 1000 non-null   int64
#  8   tax_5%                   1000 non-null   float64
#  9   total                    1000 non-null   float64
#  10  date                     1000 non-null   datetime64[ns]
#  11  time                     1000 non-null   object
#  12  payment                  1000 non-null   object
# ...

# %%
df["time"] = pd.to_timedelta(df["time"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File timedeltas.pyx:438, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File timedeltas.pyx:470, in pandas._libs.tslibs.timedeltas._item_to_timedelta64_fastpath()
#
# TypeError: Expected unicode, got Timestamp
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df["time"] = pd.to_timedelta(df["time"])
#
# File d:\Miniconda\envs\BSD-005\lib\site-packages\pandas\core\tools\timedeltas.py:201, in to_timedelta(arg, unit, errors)
#     199     return arg
#     200 elif isinstance(arg, ABCSeries):
# --> 201     values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     202     return arg._constructor(values, index=arg.index, name=arg.name)
#     203 elif isinstance(arg, ABCIndex):
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns.tolist()
# Out:
# ['Invoice_ID',
#  'Branch',
#  'City',
#  'Customer_type',
#  'Gender',
#  'Product_line',
#  'Unit_price',
#  'Quantity',
#  'Tax_5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross_margin_percentage',
#  'gross_income',
#  'Rating']

# %%
df.columns = df.columns.str.lower()

# %%
df.columns.tolist()
# Out:
# ['invoice_id',
#  'branch',
#  'city',
#  'customer_type',
#  'gender',
#  'product_line',
#  'unit_price',
#  'quantity',
#  'tax_5%',
#  'total',
#  'date',
#  'time',
#  'payment',
#  'cogs',
#  'gross_margin_percentage',
#  'gross_income',
#  'rating']

# %%
df
# Out:
#       invoice_id branch       city customer_type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product_line  unit_price  quantity   tax_5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...
